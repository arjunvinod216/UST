# %%
import pandas as pd

# %%
# a  Read data from csv file fire department of New York City (FDNY)

# b  View content of the data

# %%
fire_dept = pd.read_csv('FDNY.csv')
display(fire_dept)
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# ...

# %%
# c  View first five records

# %%
fire_dept.head()
# Out:
#                                         FacilityName       FacilityAddress  \
# 0                                       FacilityName       FacilityAddress
# 1                                 Engine 4/Ladder 15       42 South Street
# 2                                Engine 10/Ladder 10    124 Liberty Street
# 3                                           Engine 6     49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...  100-104 Duane Street
#
#      Borough
# 0    Borough
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
# d Skip the first row from dataset while reading

# %%
fire_dept[1:]
# Out:
#                                           FacilityName  \
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                             Ladder 8
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# 5       14 North Moore Street      Manhattan
# ...

# %%
# e View first five records from fixed dataset

# %%
fire_dept[1:].head()
# Out:
#                                         FacilityName        FacilityAddress  \
# 2                                Engine 10/Ladder 10     124 Liberty Street
# 3                                           Engine 6      49 Beekman Street
# 4  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 5                                           Ladder 8  14 North Moore Street
# 6                                  Engine 9/Ladder 6        75 Canal Street
#
#      Borough
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan
# 5  Manhattan
# 6  Manhattan

# %%
# f Show statistics of the dataset.

# %%
fire_dept.count()
# Out:
# FacilityName       218
# FacilityAddress    218
# Borough            218
# dtype: int64

# %%
fire_dept.shape
# Out:
# (219, 3)

# %%
# g Display columns of the dataset

# %%
fire_dept.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
# h Show the datatypes of each column

# %%
fire_dept.dtypes
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
# i View index of dataset

# %%
fire_dept.index
# Out:
# RangeIndex(start=1, stop=219, step=1)

# %%
# j  Find the total number of fire department facilities in New York city.

# %%
fire_dept1['FacilityName'].size
# Out:
# 218

# %%
fire_dept1['Borough'].value_counts()
# Out:
# Brooklyn         66
# Queens           50
# Manhattan        48
# Bronx            34
# Staten Island    20
# Name: Borough, dtype: int64

# %%
# k View FDNY information for each borough.

# %%
fire_dept.groupby(['Borough']).describe()
# Out:
#               FacilityName         \
#                      count unique
# Borough
# Borough                  1      1
# Bronx                   34     34
# Brooklyn                66     66
# Manhattan               48     48
# Queens                  50     50
# Staten Island           20     20
#
#                                                                        \
#                                                              top freq
# Borough
# Borough                                             FacilityName    1
# Bronx                           Engine 60/Ladder 17/Battalion 14    1
# Brooklyn       Engine 207/Ladder 110/Battalion 31/Division 11...    1
# Manhattan                                     Engine 4/Ladder 15    1
# Queens                                     Engine 258/Ladder 115    1
# Staten Island                                           Marine 9    1
#
#               FacilityAddress
#                         count unique                          top freq
# ...

# %%
# l Find the total number of fire department facilities in each borough.(Use groupby)

# %%
fire_dept.groupby(['Borough']).size()
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           50
# Staten Island    20
# dtype: int64

# %%
# m Find total number of fire department facilities in Manhattan (use groupby)

# %%
fire_dept[fire_dept['Borough']=='Manhattan']
# Out:
#                                          FacilityName  \
# 1                                  Engine 4/Ladder 15
# 2                                 Engine 10/Ladder 10
# 3                                            Engine 6
# 4   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                            Ladder 8
# 6                                   Engine 9/Ladder 6
# 7                     Engine 15/Ladder 18/Battalion 4
# 8                                 Engine 28/Ladder 11
# 9                                            Engine 5
# 10                                          Engine 55
# 11                               Ladder 20/Division 1
# 12                     Engine 24/Ladder 5/Battalion 2
# 13                                 Engine 33/Ladder 9
# 14                               Ladder 3/Battalion 6
# 15                                           Squad 18
# 16                                Engine 34/Ladder 21
# ...

# %%
# n Clean the dataset and drop null/nan value

# %%
fire_dept.dropna(inplace =True)
fire_dept
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# ...
